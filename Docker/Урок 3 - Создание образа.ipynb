# %% [markdown]
# ![image.png](attachment:984f3575-99df-407a-84ff-e56e2025803c.png)

# %% [markdown]
# ![image.png](attachment:2e5f9745-c239-4b1b-9477-8705b02b63bf.png)

# %% [markdown]
# ![image.png](attachment:7d4dc3f1-b8cd-4696-b714-5222d7038779.png)

# %% [markdown]
# ![image.png](attachment:16e5efe7-cc8f-4ba5-8eb1-51a5ba66644e.png)

# %% [markdown]
# ![image.png](attachment:f405edcc-e3a8-47d3-965c-b01251ea520c.png)

# %% [markdown]
# ![image.png](attachment:a4363ecf-97a1-4355-a537-2fda608b0ccd.png)

# %% [markdown]
# ![image.png](attachment:cb8d7ddd-1a3f-49de-ba21-bbe7fe8a8933.png)

# %% [markdown]
# ### Во втором примере внизу 'Hello' взялся из кэша и поэтому команда не исполнилась
# ![image.png](attachment:ae2c9fd3-1caf-4268-8f2d-fb102c698066.png)

# %% [markdown]
# ### Чтобы ранее используемые в слоях команды не закэшировались, рекомендуется установку и обновления программ объединить одной командой
# ![image.png](attachment:1395050e-f64c-454b-ab1b-8bda6edb279c.png)

# %% [markdown]
# ![image.png](attachment:119aa6e7-7ce7-42b7-9782-5ccf0892721c.png)

# %% [markdown]
# ### Хоть во втором примере файл удаляется, но слой его содержащий свой размер не меняет. В контейнере файла не будет, а в образе останется
# ![image.png](attachment:b9b315ca-042d-4ea0-84d1-62be719048c1.png)

# %% [markdown]
# ![image.png](attachment:eceb37a8-4a30-4d64-b10e-4f74c4e92ed0.png)

# %% [markdown]
# ### Пароли нельзя класть в образ, поэтому их лучше поместить в .dockerignore

# %% [markdown]
# ### Собрали через vi (для выхода :wq) минимальный кастомный образ
# ![image.png](attachment:5dedb4ba-c4fb-4229-9e53-22ba834e7e38.png)
# ![image.png](attachment:b8775855-cfe7-4d9b-bd6e-f2f0c77a32cd.png)

# %% [markdown]
# ### Флаг -f в `docker build` указывается какой конкретно докерфайл требуется брать (иногда бывают Dockerfile.dev и др.)

# %% [markdown]
# ![image.png](attachment:c66a2821-7b4d-4512-8ab4-0179ee599633.png)
# ### При запуске контейнера мы сразу же оказались в рабочей директории

# %% [markdown]
# ![image.png](attachment:68a625a9-0e29-49a9-aa22-d5f054167a34.png)

# %% [markdown]
# ![image.png](attachment:97f5814e-dc24-415b-993b-fe7e99f45e99.png)
# ![image.png](attachment:734c7c15-490e-45e9-85af-b1b3c3d6d948.png)
# ### Копируем наш скрипт в контейнер

# %% [markdown]
# ![image.png](attachment:13f7cd25-4bb7-48b3-af71-b691fb7ee432.png)
# ### Создаем новый контейнер на базе нового образа

# %% [markdown]
# ### Запустим скрипт
# ![image.png](attachment:18b4678b-d0e4-4c62-90a0-e3078eb2f4d4.png)

# %% [markdown]
# ![image.png](attachment:5f29a8da-f517-49a5-ba09-81695e3b715c.png)

# %% [markdown]
# ![image.png](attachment:b88b683f-d6c5-4126-9d81-f4b5ba4b2fb9.png)

# %% [markdown]
# ### Всегда используйет флаг `-y` при установке пакетов чтобы не выпала ошибка
# ![image.png](attachment:d039b7e0-71a5-433a-aa24-6f1c7b2c5ca9.png)
# ### Собрали новый билд
# ![image.png](attachment:a33516c7-2235-4aeb-a80f-c4e0c8dadb4f.png)

# %% [markdown]
# ### Vim есть и все работает
# ![image.png](attachment:6188713f-552f-419e-9fb7-b37e96f1e059.png)
# ![image.png](attachment:d4c60ddc-112c-4096-acd0-d6b062cd33b0.png)

# %% [markdown]
# ![image.png](attachment:9bc671fa-67c3-46a9-8590-0c3d7ca0af47.png)

# %% [markdown]
# ### Некоторые команды можно прямо из Github находить для докера
# ![image.png](attachment:e8058ba2-582e-40d1-91d8-417b8633d7f7.png)
# ![image.png](attachment:8d68884a-87e4-4690-8269-ae40b65d2b28.png)
# ![image.png](attachment:bc489ee1-c964-4e8b-8dd7-22e1cd36bb95.png)

# %% [markdown]
# ![image.png](attachment:347bbddb-0219-439d-9c44-88ab058ede71.png)
# ### В CMD будет перезапись в случае добавления аргументов, а вот с ENTRYPOINT сразу можно передать аргументом файл, который требуется открыть

# %% [markdown]
# # Добавим Entrypoint
# ![image.png](attachment:776e0e32-c7ba-461b-b676-3a4af71fc4f0.png)
# ![image.png](attachment:e71425e3-b02d-49b2-8acb-03f9a7bd78fa.png)

# %% [markdown]
# ### Интерактивный режим подразумевает открытие потока ввода. Снизу пример взаимодействия двух команд запуска, одна вызывает zsh, а другая открывает конкретный файл
# ![image.png](attachment:19fe7e98-31eb-4326-bab4-8371bb793c5e.png)

# %% [markdown]
# ![image.png](attachment:460770a1-4fae-47a5-b818-07266817d3b3.png)
# ### CMD можно переопределить, а другой выведет инструкцию по-любому

# %% [markdown]
# ### Можно явно указать переход в zsh, через флаг --entrypoint
# ![image.png](attachment:1da65fb6-93ef-4ddb-aa48-7c0def92a9dc.png)

# %% [markdown]
# ![image.png](attachment:1071a9fa-49ae-4eeb-b9b5-ba519ab1b82e.png)
